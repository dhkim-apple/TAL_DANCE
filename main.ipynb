# %%
import sys
import os
sys.path.append('..')
from ultralytics import YOLO

import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO('../yolov8n-pose.pt')

results = model.train(data = 'talDance-pose.yaml', epochs = 100, imgsz = 2160)
# Out:
# New https://pypi.org/project/ultralytics/8.0.166 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.162 🚀 Python-3.8.17 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100 80GB PCIe, 81051MiB)
# ...
